// %% [markdown]
// <h3>Curso de HTML</h3>
// <a href="queeshtml.html">Introducción</a>
// <details>
// <summary>Tema 1: La Funci&oacute;n de Demanda y de Oferta</summary>
// <ol>
// <li>
// <p>La Funci&oacute;n de Demanda.</p>
// <ol>
// <li><a href="queeshtml.html">Definici&oacute;n y representaci&oacute;n gr&aacute;fica.</a></li>
// <li><a href="queeshtml.html">Cantidad demandada versus &ldquo;Demanda&rdquo;</a></li>
// <li><a href="queeshtml.html">Factores subyacentes a la funci&oacute;n de demanda.</a></li>
// <li><a href="queeshtml.html">Movimientos a lo largo de la curva y movimientos de la curva.</a></li>
// </ol>
// </li>
// <li>
// <p>La Funci&oacute;n de Oferta.</p>
// <ol>
// <li><a href="queeshtml.html">Definici&oacute;n y representaci&oacute;n gr&aacute;fica.</a></li>
// <li><a href="queeshtml.html">Cantidad ofrecida versus &ldquo;Oferta&rdquo;</a></li>
// <li><a href="queeshtml.html">Factores subyacentes a la funci&oacute;n de oferta.</a></li>
// <li><a href="queeshtml.html">Movimientos a lo largo de la curva y movimientos de la curva.</a></li>
// </ol>
// </li>
// <li>
// <p>Desplazamientos de la funci&oacute;n de oferta y de demanda.</p>
// <ol>
// <li><a href="queeshtml.html">Desplazamientos simult&aacute;neos.</a></li>
// </ol>
// </li>
// <li>
// <p>La funci&oacute;n de oferta y de demanda: equilibrio.</p>
// </li>
// <li>
// <p>La funci&oacute;n de oferta y de demanda: individual y de mercado.</p>
// </li>
// </ol>
// </details>
// <details>
// <summary>Tema 2: Equilibrio en los mercados</summary>
// <ol>
// <li>
// <p>Diferentes enfoques en la determinaci&oacute;n del precio de los bienes: &ldquo;La paradoja del valor&rdquo;</p>
// <ol>
// <li><a href="queeshtml.html">Escuela cl&aacute;sica: &ldquo;valor trabajo&rdquo; (predominio funci&oacute;n de oferta)</a></li>
// <li><a href="queeshtml.html">Escuela marginalista: &ldquo;utilidad marginal&rdquo; (predominio funci&oacute;n demanda)</a></li>
// <li><a href="queeshtml.html">Escuela marshaliana: &ldquo;modelo de las tijeras&rdquo; (interacci&oacute;n demanda-oferta).</a></li>
// </ol>
// </li>
// <li>
// <p>El equilibrio en el mercado dom&eacute;stico.</p>
// <ol>
// <li><a href="queeshtml.html">Concepto de equilibrio.</a></li>
// <li><a href="queeshtml.html">La Ley de la Oferta y de la Demanda.</a></li>
// <li><a href="queeshtml.html">Funcionamiento de las fuerzas del mercado.</a></li>
// <li><a href="queeshtml.html">Excedentes del consumidor y del productor.</a></li>
// <li><a href="queeshtml.html">Equilibrio y eficiencia.</a></li>
// </ol>
// </li>
// <li>
// <p>El equilibrio en los mercados transnacionales.</p>
// <ol>
// <li><a href="queeshtml.html">Ventaja comparativa y ganancias del comercio.</a></li>
// <li><a href="queeshtml.html">Relaci&oacute;n entre el precio de equilibrio dom&eacute;stico y el mundial.</a></li>
// <li><a href="queeshtml.html">Efectos del comercio sobre el precio de equilibrio dom&eacute;stico del pa&iacute;s importador y del pa&iacute;s exportador.</a></li>
// </ol>
// </li>
// </ol>
// </details>
//
// <details>
// <summary>Tema 3: Desequilibrio: Causas y Mecanismos de ajuste hacia el equilibrio.</summary>
// <ol>
// <li>
// <p>Concepto de desequilibrio.</p>
// </li>
// <li>
// <p>Tipos de desequilibrio.</p>
// </li>
// <li>
// <p>Causas del desequilibrio.</p>
// <ol>
// <li><a href="queeshtml.html">Incumplimiento de los planes de producción.</a></li>
// <li><a href="queeshtml.html">Inclumplimiento de la ley de la Demanda o de la Oferta.</a></li>
// <li><a href="queeshtml.html">Información incompleta (mercados opacos).</a></li>
// <li><a href="queeshtml.html">Intervenciones estatales: controles de precios (mercados regulados).</a></li>
// <li><a href="queeshtml.html">Retardos en las respuestas de los agentes: Modelo de la telaraña.</a></li>
// </ol>
// </li>
// <li>
// <p>Mecanismos de ajuste hacia el equilibrio:</p>
// <ol>
// <li><a href="queeshtml.html">Arbitraje.</a></li>
// <li><a href="queeshtml.html">Especulación.</a></li>
// </ol>
// </li>
// </ol>
// </details>
//
// <details>
// <summary>Tema 4: Elasticidad de la demanda y de la oferta.</summary>
// <ol>
// <li>
// <p>Concepto de elasticidad.</p>
// </li>
// <li>
// <p>Elasticidad-precio de la demanda.</p>
// <ol>
// <li><a href="queeshtml.html">Elasticidad-precio en un punto de la función de demanda.</a></li>
// <li><a href="queeshtml.html">Elasticidad-arco entre dos puntos de la función de demanda.</a></li>
// <li><a href="queeshtml.html">Relación entre Elasticidad-precio e ingresos totales.</a></li>
// </ol>
// </li>
// <li>
// <p>Elasticidad renta de la demanda.</p>
// <ol>
// <li><a href="queeshtml.html">Bienes inferiores, normales y de lujo.</a></li>
// </ol>
// </li>
// <li>
// <p>Elasticidad cruzada de la demanda.</p>
// <ol>
// <li><a href="queeshtml.html">Bienes complementarios y sustitutivos.</a></li>
// </ol>
// </li>
// <li>
// <p>Elasticidad-precio de la oferta.</p>
// </li>
// <li>
// <p>Diferentes elasticidades de las funciones de demanda y de oferta a corto plazo y a largo
// plazo.</p>
// </li>
// </ol>
// </details>
